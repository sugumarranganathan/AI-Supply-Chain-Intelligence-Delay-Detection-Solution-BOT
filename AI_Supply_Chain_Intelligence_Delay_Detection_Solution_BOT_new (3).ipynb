# %%
# !git clone https://github.com/sugumarranganathan/AI-Supply-Chain-Intelligence-Delay-Detection-Solution-BOT.git
# Out:
# fatal: destination path 'AI-Supply-Chain-Intelligence-Delay-Detection-Solution-BOT' already exists and is not an empty directory.

# %%
# %cd AI-Supply-Chain-Intelligence-Delay-Detection-Solution-BOT
# Out:
# /content/AI-Supply-Chain-Intelligence-Delay-Detection-Solution-BOT

# %%
# !pip install -r requirements.txt

# %%
from src.rag.loader import DocumentLoader

loader = DocumentLoader()

docs = loader.load_documents()

print(len(docs))
# Out:
# 5

# %%
# !pip install -U langchain-text-splitters

# %%
from src.rag.vector_store import VectorStore

vector_store = VectorStore()
vector_store.build_vector_store()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
from google.colab import userdata
import os

# Read your Colab secret
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY_3")

# Verify it's set
print("Key loaded:", os.environ["GROQ_API_KEY"][:10] + "...")
# Out:
# Key loaded: gsk_EftwBA...

# %%
! python app.py
# Out:
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 4435.50it/s]
# /content/AI-Supply-Chain-Intelligence-Delay-Detection-Solution-BOT/app.py:212: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://7f2e3e4437ed094eb8.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...
# Input Node
# ...
# Customer Lookup Node
# ...
# Shipment Found: SHP1002
# ...
# Retriever Node
# ...
# Shipment Node
# ...
# Shipment ID      : SHP1002
# Status           : In Transit
# Supplier ID      : SUP002
# Warehouse ID     : WH002
# Destination City : Bengaluru
# ...
# Supplier Node
# ...
# Supplier ID     : SUP002
# ...
